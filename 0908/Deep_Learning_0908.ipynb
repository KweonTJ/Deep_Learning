# %% [markdown]
# <a href="https://colab.research.google.com/github/KweonTJ/Deep_Learning/blob/main/Deep_Learning_0908.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Deep Learning
# - 2026년 9월 8일
# - 딥러닝, 코랩, 아나콘다, 파이썬 기본 사용 방법 학습

# %%
1+2
# Out:
# 3

# %%
3**2
# Out:
# 9

# %%
type(10)
# Out:
# int

# %%
type(2.718)
# Out:
# float

# %%
type("hello")
# Out:
# str

# %%
x=10
print(x)
# Out:
# 10

# %%
for i in [1, 2, 3]:
  print (i)
# Out:
# 1
# 2
# 3

# %%
def hello():
  print("Hello World!")

hello()
# Out:
# Hello World!

# %%
import numpy as np
x=np.array([1.0, 2.0, 3.0])
y=np.array([2.0, 4.0, 6.0])


print(x)
print(x+y)
print(x-y)
print(x*y)
print(x/y)
# Out:
# [1. 2. 3.]
# [3. 6. 9.]
# [-1. -2. -3.]
# [ 2.  8. 18.]
# [0.5 0.5 0.5]

# %%
x+y
# Out:
# array([3., 6., 9.])

# %%
x-y
# Out:
# array([-1., -2., -3.])

# %%
x*y
# Out:
# array([ 2.,  8., 18.])

# %%
x/y
# Out:
# array([0.5, 0.5, 0.5])
